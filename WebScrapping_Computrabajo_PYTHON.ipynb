# %% [markdown]
# <a href="https://colab.research.google.com/github/andrespaz1991/WebScrapping-Computrabajo-PYTHON/blob/main/WebScrapping_Computrabajo_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# web scraping

# %%
class trabajo:
  def computrabajo(self,palabra,imprimir):
    #!pip3 install beautifulsoup4
    #!pip install html2text
    #imprimir=False
    from bs4 import BeautifulSoup
    import requests 
    import re
    url="https://www.computrabajo.com.co/trabajo-de-"+palabra
    req = requests.get(url)
    soup = BeautifulSoup(req.text, "lxml")
    books=soup.find_all("div",class_="w100")
    f = open('empleo.html','w')
    for each_book in books:
        print("#"*32)
        print(each_book)
        texto=each_book.find("h1")
        destFile = r"empleo.html"
        with open(destFile, 'a') as f:
          f.write(str(texto))
          if imprimir==1:
            print(texto.text)
    f.close()
    ####################
    if imprimir!=1:
      from google.colab.output import eval_js
      print(eval_js("google.colab.kernel.proxyPort(8000)"))
      # !python -m http.server 8000

MiTrabajo=trabajo()
MiTrabajo.computrabajo("python",1) #1 para imprimir  y cero para servidor
# Out:
# Found the URL:
# Found the URL:
# Found the URL: https://www.computrabajo.com.co
# Found the URL: https://www.computrabajo.com.co
# Found the URL: https://empresa.computrabajo.com.co
# Found the URL: /empresas/
# Found the URL: https://www.computrabajo.com.co/salarios/
# Found the URL: https://blog.computrabajo.com.co/candidato/
# Found the URL: https://www.computrabajo.com.co
# Found the URL: /empleos-de-informatica-y-telecom
# Found the URL: /empleos-de-ingenieria-y-tecnico
# Found the URL: /empleos-de-educacion-y-universidad
# Found the URL: /empleos-de-administracion-y-oficina
# Found the URL: /empleos-de-otros
# Found the URL: /empleos-de-callcenter-telemercadeo
# Found the URL: /empleos-de-mercadeo-publicidad-comunicacion
# Found the URL: /empleos-de-economia-y-contabilidad
# Found the URL: /trabajo-de-python-en-bogota-dc
# Found the URL: /trabajo-de-python-en-antioquia
# Found the URL: /trabajo-de-python-en-valle-del-cauca
# Found the URL: /trabajo-de-python-en-atlantico
# ...
